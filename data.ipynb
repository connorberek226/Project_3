# %%
import pandas as pd

# %%
states = pd.read_csv("data/stateData.csv")
covid_df = pd.read_csv("data/us-states.csv")
#lat_long = pd.read_csv("data/CV_LatLon_21Jan_12Mar.csv")
covid_df.head()
#states.head()
#lat_long.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
cleaned_states = states.fillna(0)
cleaned_covid = covid_df.fillna(0)

# %%
cleaned_states = cleaned_states.rename(columns={"GeoName": "state"})
cleaned_states
# Out:
#      GeoFips      state  LineCode                              Description  \
# 0       1000    Alabama         1    Personal income (millions of dollars)
# 1       1000    Alabama         2                  Population (persons) 1/
# 2       1000    Alabama         3  Per capita personal income (dollars) 2/
# 3       2000   Alaska *         1    Personal income (millions of dollars)
# 4       2000   Alaska *         2                  Population (persons) 1/
# ..       ...        ...       ...                                      ...
# 148    55000  Wisconsin         2                  Population (persons) 1/
# 149    55000  Wisconsin         3  Per capita personal income (dollars) 2/
# 150    56000    Wyoming         1    Personal income (millions of dollars)
# 151    56000    Wyoming         2                  Population (persons) 1/
# 152    56000    Wyoming         3  Per capita personal income (dollars) 2/
#
#           2018       2019
# 0     208752.7   216449.0
# ...

# %%
cleaned_covid
# Out:
#              date          state  fips   cases  deaths
# 0      2020-01-21     Washington    53       1       0
# 1      2020-01-22     Washington    53       1       0
# 2      2020-01-23     Washington    53       1       0
# 3      2020-01-24       Illinois    17       1       0
# 4      2020-01-24     Washington    53       1       0
# ...           ...            ...   ...     ...     ...
# 12219  2020-10-10       Virginia    51  157905    3354
# 12220  2020-10-10     Washington    53   97223    2289
# 12221  2020-10-10  West Virginia    54   17913     381
# 12222  2020-10-10      Wisconsin    55  155752    1470
# 12223  2020-10-10        Wyoming    56    7455      54
#
# [12224 rows x 5 columns]

# %%
cleaned_states.to_csv("data/cleaned_csv/cleaned_stateData.csv")
cleaned_covid.to_csv("data/cleaned_csv/cleaned_us-state-covid-data.csv")
